# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'D:\projects\changellenge\PostgreSQL.csv'
t = pd.read_csv(path)
t.set_index('employee_id')['conv'].plot(kind='bar')
plt.title('Конверсия по сотрудникам')
plt.xlabel('id Сотрудника')
plt.ylabel('Конверсия, %')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Qwert\AppData\Local\Temp\ipykernel_4024\3125819744.py:1: SyntaxWarning: invalid escape sequence '\p'
#   path = 'D:\projects\changellenge\PostgreSQL.csv'
